# %% [markdown]
# # Working with Images

# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((220,330,1000,400))
# Out:
# <PIL.Image.Image image mode=RGB size=780x70>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.crop((800,800,1900,1900))
# Out:
# <PIL.Image.Image image mode=RGB size=1100x1100>
