# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace
from openai import OpenAI
import os

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Create Gemini client
client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
os.environ["OPENAI_BASE_URL"] = "https://generativelanguage.googleapis.com/v1beta/openai/"
# Make an agent with name, instructions, model

agent = Agent(name="Jokester", instructions="You are a joke teller", model="gemini-2.5-flash", )

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Error getting response: Error code: 404. (request_id: None)
# Error getting response; filtered.input=[{'content': 'Tell a joke about Autonomous AI Agents', 'role': 'user'}]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[18], line 4
#       1 # Run the joke with Runner.run(agent, prompt) then print final_output
#       3 with trace("Telling a joke"):
# ----> 4     result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
#       5     print(result.final_output)
#
# File ~\anaconda3\Lib\site-packages\agents\run.py:223, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     173 """
#     174 Run a workflow starting at the given agent.
#     175
#    (...)    219     type of the output.
#     220 """
#     222 runner = DEFAULT_AGENT_RUNNER
# --> 223 return await runner.run(
#     224     starting_agent,
#     225     input,
#     226     context=context,
#     227     max_turns=max_turns,
#     228     hooks=hooks,
#     229     run_config=run_config,
#     230     error_handlers=error_handlers,
#     231     previous_response_id=previous_response_id,
#     232     auto_previous_response_id=auto_previous_response_id,
#     233     conversation_id=conversation_id,
#     234     session=session,
#     235 )
#
# File ~\anaconda3\Lib\site-packages\agents\run.py:1059, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1057         raise
#    1058 else:
# -> 1059     turn_result = await model_task
#    1061 input_guardrail_results.extend(sequential_results)
#    1062 input_guardrail_results.extend(parallel_results)
#
# File ~\anaconda3\Lib\site-packages\agents\run_internal\run_loop.py:1504, in run_single_turn(agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy)
#    1501 if isinstance(input, list):
#    1502     input = normalize_input_items_for_api(input)
# -> 1504 new_response = await get_new_response(
#    1505     agent,
#    1506     system_prompt,
#    1507     input,
#    1508     output_schema,
#    1509     all_tools,
#    1510     handoffs,
#    1511     hooks,
#    1512     context_wrapper,
#    1513     run_config,
#    1514     tool_use_tracker,
#    1515     server_conversation_tracker,
#    1516     prompt_config,
#    1517     session=session,
#    1518     session_items_to_rewind=session_items_to_rewind,
#    1519 )
#    1521 return await get_single_step_result_from_response(
#    1522     agent=agent,
#    1523     original_input=original_input,
#    (...)   1532     tool_use_tracker=tool_use_tracker,
#    1533 )
#
# File ~\anaconda3\Lib\site-packages\agents\run_internal\run_loop.py:1599, in get_new_response(agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind)
#    1596     logger.debug("No conversation_id available for request")
#    1598 try:
# -> 1599     new_response = await model.get_response(
#    1600         system_instructions=filtered.instructions,
#    1601         input=filtered.input,
#    1602         model_settings=model_settings,
#    1603         tools=all_tools,
#    1604         output_schema=output_schema,
#    1605         handoffs=handoffs,
#    1606         tracing=get_model_tracing_impl(
#    1607             run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1608         ),
#    1609         previous_response_id=previous_response_id,
#    1610         conversation_id=conversation_id,
#    1611         prompt=prompt_config,
#    1612     )
#    1613 except Exception as exc:
#    1614     from openai import BadRequestError
#
# File ~\anaconda3\Lib\site-packages\agents\models\openai_responses.py:373, in OpenAIResponsesModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     371 with response_span(disabled=tracing.is_disabled()) as span_response:
#     372     try:
# --> 373         response = await self._fetch_response(
#     374             system_instructions,
#     375             input,
#     376             model_settings,
#     377             tools,
#     378             output_schema,
#     379             handoffs,
#     380             previous_response_id=previous_response_id,
#     381             conversation_id=conversation_id,
#     382             stream=False,
#     383             prompt=prompt,
#     384         )
#     386         if _debug.DONT_LOG_MODEL_DATA:
#     387             logger.debug("LLM responded")
#
# File ~\anaconda3\Lib\site-packages\agents\models\openai_responses.py:579, in OpenAIResponsesModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, previous_response_id, conversation_id, stream, prompt)
#     565 create_kwargs = self._build_response_create_kwargs(
#     566     system_instructions=system_instructions,
#     567     input=input,
#    (...)    575     prompt=prompt,
#     576 )
#     578 if not stream:
# --> 579     response = await self._client.responses.create(**create_kwargs)
#     580     return cast(Response, response)
#     582 streaming_response = getattr(self._client.responses, "with_streaming_response", None)
#
# File ~\anaconda3\Lib\site-packages\openai\resources\responses\responses.py:2561, in AsyncResponses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2522 async def create(
#    2523     self,
#    2524     *,
#    (...)   2559     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2560 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2561     return await self._post(
#    2562         "/responses",
#    2563         body=await async_maybe_transform(
#    2564             {
#    2565                 "background": background,
#    2566                 "context_management": context_management,
#    2567                 "conversation": conversation,
#    2568                 "include": include,
#    2569                 "input": input,
#    2570                 "instructions": instructions,
#    2571                 "max_output_tokens": max_output_tokens,
#    2572                 "max_tool_calls": max_tool_calls,
#    2573                 "metadata": metadata,
#    2574                 "model": model,
#    2575                 "parallel_tool_calls": parallel_tool_calls,
#    2576                 "previous_response_id": previous_response_id,
#    2577                 "prompt": prompt,
#    2578                 "prompt_cache_key": prompt_cache_key,
#    2579                 "prompt_cache_retention": prompt_cache_retention,
#    2580                 "reasoning": reasoning,
#    2581                 "safety_identifier": safety_identifier,
#    2582                 "service_tier": service_tier,
#    2583                 "store": store,
#    2584                 "stream": stream,
#    2585                 "stream_options": stream_options,
#    2586                 "temperature": temperature,
#    2587                 "text": text,
#    2588                 "tool_choice": tool_choice,
#    2589                 "tools": tools,
#    2590                 "top_logprobs": top_logprobs,
#    2591                 "top_p": top_p,
#    2592                 "truncation": truncation,
#    2593                 "user": user,
#    2594             },
#    2595             response_create_params.ResponseCreateParamsStreaming
#    2596             if stream
#    2597             else response_create_params.ResponseCreateParamsNonStreaming,
#    2598         ),
#    2599         options=make_request_options(
#    2600             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2601         ),
#    2602         cast_to=Response,
#    2603         stream=stream or False,
#    2604         stream_cls=AsyncStream[ResponseStreamEvent],
#    2605     )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1875     warnings.warn(
#    1876         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1877         "Please pass raw bytes via the `content` parameter instead.",
#    1878         DeprecationWarning,
#    1879         stacklevel=2,
#    1880     )
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1666             await err.response.aread()
#    1668         log.debug("Re-raising status error")
# -> 1669         raise self._make_status_error_from_response(err.response) from None
#    1671     break
#    1673 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
