# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series

# %%
import numpy as np
import pandas as pd

# %%
lables = ['a','b','c']
data = [10,20,30]

# %%
pd.Series(data= data, index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
dic = {'a':10, 'b':20, 'c':30}
ser = pd.Series(dic)

# %%
ser['a']
# Out:
# np.int64(10)
