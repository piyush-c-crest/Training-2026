# %% [markdown]
# # Dataframe

# %%
import pandas as pd

# %%
from numpy.random import randn

# %%
df  = pd.DataFrame(randn(5,4),['A','B','C','D','E'], ['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# B -0.378513  0.575466 -2.012051 -0.381453
# C -1.444165  0.646565 -0.777054  0.115287
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.W
# Out:
# A   -0.372658
# B   -0.378513
# C   -1.444165
# D    1.568436
# E    0.140624
# Name: W, dtype: float64

# %%
df[['W','X']]
# Out:
#           W         X
# A -0.372658  1.754495
# B -0.378513  0.575466
# C -1.444165  0.646565
# D  1.568436 -0.411680
# E  0.140624  0.522233

# %%
df['new'] = [1,2,3,4,5]

# %%
df
# Out:
#           W         X         Y         Z  new
# A -0.372658  1.754495  0.507104 -0.282495    1
# B -0.378513  0.575466 -2.012051 -0.381453    2
# C -1.444165  0.646565 -0.777054  0.115287    3
# D  1.568436 -0.411680 -0.051486  0.168959    4
# E  0.140624  0.522233 -1.403687 -0.172420    5

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# B -0.378513  0.575466 -2.012051 -0.381453
# C -1.444165  0.646565 -0.777054  0.115287
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
df.drop('E')
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# B -0.378513  0.575466 -2.012051 -0.381453
# C -1.444165  0.646565 -0.777054  0.115287
# D  1.568436 -0.411680 -0.051486  0.168959

# %%
df.shape
# Out:
# (5, 4)

# %%
df.loc[['A','C']]
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# C -1.444165  0.646565 -0.777054  0.115287

# %%
df.iloc[[1,3]]
# Out:
#           W         X         Y         Z
# B -0.378513  0.575466 -2.012051 -0.381453
# D  1.568436 -0.411680 -0.051486  0.168959

# %%
df
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# B -0.378513  0.575466 -2.012051 -0.381453
# C -1.444165  0.646565 -0.777054  0.115287
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A       NaN  1.754495  0.507104       NaN
# B       NaN  0.575466       NaN       NaN
# C       NaN  0.646565       NaN  0.115287
# D  1.568436       NaN       NaN  0.168959
# E  0.140624  0.522233       NaN       NaN

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
df[(df['W'] > 0 ) & (df['X'] < 0)]
# Out:
#           W        X         Y         Z
# D  1.568436 -0.41168 -0.051486  0.168959

# %%
df[(df['W'] > 0 ) | (df['X'] < 0)]
# Out:
#           W         X         Y         Z
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
df
# Out:
#           W         X         Y         Z
# A -0.372658  1.754495  0.507104 -0.282495
# B -0.378513  0.575466 -2.012051 -0.381453
# C -1.444165  0.646565 -0.777054  0.115287
# D  1.568436 -0.411680 -0.051486  0.168959
# E  0.140624  0.522233 -1.403687 -0.172420

# %%
df.reset_index(drop=True)
# Out:
#           W         X         Y         Z
# 0 -0.372658  1.754495  0.507104 -0.282495
# 1 -0.378513  0.575466 -2.012051 -0.381453
# 2 -1.444165  0.646565 -0.777054  0.115287
# 3  1.568436 -0.411680 -0.051486  0.168959
# 4  0.140624  0.522233 -1.403687 -0.172420

# %%
new_index = 'AA BB CC DD EE'.split()

# %%
df['new_index'] = new_index

# %%
df
# Out:
#           W         X         Y         Z new_index
# A -0.372658  1.754495  0.507104 -0.282495        AA
# B -0.378513  0.575466 -2.012051 -0.381453        BB
# C -1.444165  0.646565 -0.777054  0.115287        CC
# D  1.568436 -0.411680 -0.051486  0.168959        DD
# E  0.140624  0.522233 -1.403687 -0.172420        EE

# %%
df.set_index('new_index')
# Out:
#                   W         X         Y         Z
# new_index
# AA        -0.372658  1.754495  0.507104 -0.282495
# BB        -0.378513  0.575466 -2.012051 -0.381453
# CC        -1.444165  0.646565 -0.777054  0.115287
# DD         1.568436 -0.411680 -0.051486  0.168959
# EE         0.140624  0.522233 -1.403687 -0.172420

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(randn(6,2),hier_index, ['A','B'])
df
# Out:
#              A         B
# G1 1 -1.851491  0.416364
#    2 -1.166693 -0.098909
#    3  0.251904  1.465342
# G2 1  0.241715 -1.480578
#    2  0.670342  2.073403
#    3  1.425565 -0.132264

# %%
df.loc['G1'].loc[2]
# Out:
# A   -1.166693
# B   -0.098909
# Name: 2, dtype: float64

# %%
df.index.names = ['Groups','num']

# %%
df
# Out:
#                    A         B
# Groups num
# G1     1   -1.851491  0.416364
#        2   -1.166693 -0.098909
#        3    0.251904  1.465342
# G2     1    0.241715 -1.480578
#        2    0.670342  2.073403
#        3    1.425565 -0.132264

# %%
df.loc['G2'].iloc[1,1]
# Out:
# np.float64(2.0734031778791993)

# %%
df.xs(1,level='num')
# Out:
#                A         B
# Groups
# G1     -1.851491  0.416364
# G2      0.241715 -1.480578
