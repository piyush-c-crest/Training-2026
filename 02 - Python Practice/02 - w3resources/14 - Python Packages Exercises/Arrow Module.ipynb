# %%
# !pip install arrow
# Out:
# Requirement already satisfied: arrow in c:\users\piyushchunara\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\piyushchunara\anaconda3\lib\site-packages (from arrow) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\piyushchunara\anaconda3\lib\site-packages (from arrow) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\piyushchunara\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow) (1.17.0)

# %%
import arrow
a = arrow.utcnow()
print("Current datetime:")
print(a)
print("\nCurrent local datetime:")
b = arrow.now()
print(b)
# Out:
# Current datetime:
# 2026-01-16T12:35:55.282924+00:00
#
# Current local datetime:
# 2026-01-16T18:05:55.283796+05:30

# %%
import arrow
i = arrow.get(1857900545)
print("Date from integers: ")
print(i)
f = arrow.get(1857900545.234323)
print("\nDate from floats: ")
print(f)
# Out:
# Date from integers:
# 2028-11-15T11:29:05+00:00
#
# Date from floats:
# 2028-11-15T11:29:05.234323+00:00
