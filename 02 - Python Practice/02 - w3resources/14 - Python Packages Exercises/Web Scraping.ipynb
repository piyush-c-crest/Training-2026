# %%
import requests

# %%
def check(url):
    try:
        res = requests.get(url)
    except:
        print('Not Ok')
    else:
        print('OK')

# %%
check('https://quotes.toscrape.com')
# Out:
# OK

# %%
check('https://quotes.oscrape.com')
# Out:
# Not Ok

# %% [markdown]
# Write a Python program to download and display the content of robot.txt for en.wikipedia.org.

# %%
res = requests.get("https://en.wikipedia.org/robots.txt")
res.text
# Out:
# 'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'
