# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\piyushchunara\anaconda3\lib\site-packages (2.5.0)

# %%
import urllib3

http = urllib3.PoolManager()

api_url = 'https://jsonplaceholder.typicode.com/posts/1'

response = http.request('GET', api_url)

if response.status == 200:
    print("Response Data:")
    print(response.data.decode('utf-8'))
else:
    print(f"Error: Unable to fetch data. Status Code: {response.status}")
# Out:
# Response Data:
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %% [markdown]
# Write a Python program that makes a GET request with custom headers, such as User-Agent and Authorization.

# %%
import urllib3

http = urllib3.PoolManager()
api_url = 'https://jsonplaceholder.typicode.com/posts/1'

custom_headers = {
    'User-Agent': 'MyCustomUserAgent',
    'Authorization': 'Bearer'
}

response = http.request('GET', api_url, headers=custom_headers)

if response.status == 200:
    print("Response Data:")
    print(response.data.decode('utf-8'))
else:
    print(f"Error: Unable to fetch data. Status Code: {response.status}")
# Out:
# Response Data:
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
