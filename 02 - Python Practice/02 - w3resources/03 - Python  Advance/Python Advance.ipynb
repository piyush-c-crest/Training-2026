# %% [markdown]
# 1 - Class-Based Decorator for Execution Time
#
# Write a Python program to create a class-based decorator that logs the execution time of methods.

# %%
import time

# %%
def new_decorator(fun):
    
    def check_time():
        t1 = time.time()
        fun()
        t2 = time.time()

        print('time taken is : ' , t2-t1)
    return check_time

# %%
@new_decorator
def fun():
    [i**5 for i in range(10000000)]

# %%
time_check(fun)
# Out:
# time taken is :  2.6877760887145996
# 2.688082218170166
