# %% [markdown]
# ### Python Arrays
# In Python, array is a collection of items stored at contiguous memory locations. The idea is to store multiple items of the same type together. Unlike Python lists (can store elements of mixed types), arrays must have all elements of same type. Having only homogeneous elements makes it memory-efficient.

# %% [markdown]
# ### 1. Create an Array and Access Elements
#
# Write a Python program to create an array of 5 integers and display the array items. Access individual elements through indexes.

# %%
import array

# %%
a =array.array('i',[1,2,3,4,5]) # i ->interger

# %%
a
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a[2]
# Out:
# 3

# %% [markdown]
# ### 2. Append a New Item to the End of an Array
#
# Write a Python program to append a new item to the end of the array.

# %%
a.append(10)

# %%
a
# Out:
# array('i', [1, 2, 3, 4, 5, 10])
